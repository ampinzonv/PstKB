# %% [markdown]
# # Uso de Python para construir el modelo
#
# La idea es usar python para modificar el archivo de excel.

# %%
import pandas as pd
import numpy as np
# Cargar las hojas del excel como data frame separados
file_xls= '../modelData.xls'
PstKB_OF_sheet='PstKB_OF'
PstKB_OF_columns = ['NaN','ID','KB','Reaction Name','Molecule','NaN']
PstKB_OF = pd.read_excel(file_xls,sheet_name=PstKB_OF_sheet, header=None, names=PstKB_OF_columns)
biomass3_sheet ='biomass3.1'
biomass3_columns = ['KB','Changes Guevara']
biomass3 = pd.read_excel(file_xls,sheet_name=biomass3_sheet,names=biomass3_columns) 

# Dividir las columnas 'KB' y 'Changes Guevara' y crear nuevas columnas
split_columns = biomass3['KB'].str.split(expand=True)
biomass3['Metabolito'] = split_columns[0]  # Assuming the Metabolito column is the first one after the split
biomass3['KB'] = split_columns[1]
split_columns = biomass3['Changes Guevara'].str.split(expand=True)
biomass3['Changes Metabolito'] = split_columns[0]  # Assuming the Changes Metabolito column is the first one after the split
biomass3['Changes Guevara'] = split_columns[1]
biomass3.columns = ['Metabolito','Metabolito-G','KB','Guevara']
# Fusionar las columnas 'Metabolito' y 'Metabolito-G' en una nueva columna llamada 'Metabolito-Total'
biomass3['ID'] = biomass3['Metabolito'].combine_first(biomass3['Metabolito-G'])
# Eliminar las columnas originales 'Metabolito' y 'Metabolito-G' si así lo deseas
biomass3 = biomass3.drop(['Metabolito', 'Metabolito-G'], axis=1)
# Reorganizar las columnas del DataFrame
biomass3 = biomass3[['ID', 'KB', 'Guevara']]

# %%
extractSec = PstKB_OF[['ID','Reaction Name']]

mergeDf = pd.merge(extractSec, biomass3, on='ID', how='inner')
mergeDf.columns
# Out:
# Index(['ID', 'Reaction Name', 'KB', 'Guevara'], dtype='object')

# %%
# Guardar el nuevo DataFrame en un archivo CSV
mergeDf.to_csv('Code.csv', index=False)

# %% [markdown]
# ## Cargar la tabla comparativa
# Dentro del archivo hay una tabla comparativa entre 3 modelos Botero, Guevara y PstKB

# %%
Comparative_sheet='Comparative OFs'
Comparative_colums = ['Metabolito', 'Guevara 2023','Botero 2018','PstKB_Ori','PstKB_cobra']
comp_Table= pd.read_excel(file_xls,sheet_name=Comparative_sheet,names=Comparative_colums)
comp_Table = comp_Table[['Metabolito','Botero 2018','Guevara 2023','PstKB_Ori','PstKB_cobra']]
comp_Table
# Out:
#                  Metabolito Botero 2018 Guevara 2023  PstKB_Ori  \
# 0                      dATP      0.0027     0.028881   0.030000
# 1                      dTTP      0.0028     0.028881        NaN
# 2                      dCTP      0.0018     0.015417   0.026000
# 3                      dGTP     0.00166     0.015417   0.026000
# 4                       UTP      0.0028     0.095373   0.027000
# 5                       CTP      0.0032     0.050418        NaN
# 6                       GTP      0.0039     0.059181        NaN
# 7                   alanine       0.107     0.125715   0.161000
# 8                  cysteine       0.024     0.023571        NaN
# 9             aspartic acid       0.162       0.0922        NaN
# 10            glutamic acid        0.39     0.113681   0.130000
# 11            phenylalanine        0.08     0.066998        NaN
# 12                  glycine        0.14     0.119759        NaN
# 13                histidine           -     0.034132        NaN
# 14               isoleucine        0.06     0.089036        NaN
# 15                   lysine       0.001     0.111221   0.096000
# 16                  leucine        0.14     0.149333        NaN
# 17               methionine       0.002     0.038393   0.049000
# 18               asparagine        0.39     0.070447        NaN
# 19                  proline        0.01     0.084621        NaN
# 20                glutamine        0.35     0.059905   0.071000
# 21                 arginine           -     0.083304        NaN
# 22                   serine        0.21     0.136486        NaN
# 23                threonine       0.086     0.084449        NaN
# 24                   valine           -     0.115457        NaN
# 25               tryptophan        0.04     0.018506        NaN
# 26                 tyrosine        0.03     0.048038        NaN
# 27         palmitoleic acid           1      0.04043        NaN
# 28            palmitic acid           -     0.000304        NaN
# 29           linolenic acid           -     0.118671        NaN
# 30            linoleic acid           -     0.040003        NaN
# 31             stearic acid           -     0.000455        NaN
# 32               oleic acid           -     0.003467        NaN
# 33                      ATP           1     50.86403 -30.027000
# 34                      H2O           -    52.486878  30.000000
# 35                      ADP          30    50.821625        NaN
# 36                       Pi          30    50.821625        NaN
# 37                       H+         NaN    50.821625        NaN
# 38                      Ppi         NaN     0.251164        NaN
# 39          alpha-D-glucose       0.053        0.053        NaN
# 40                 D-xylose       0.282        0.282        NaN
# 41        Coniferyl alcohol       0.048        0.048        NaN
# 42          synapyl alcohol       0.056        0.056        NaN
# 43         coumaryl alcohol        0.04         0.04        NaN
# 44          beta-D-fructose       0.053            -        NaN
# 45                  sucrose       0.096            -        NaN
# 46                cellulose       0.305            -        NaN
# 47                   starch       0.265            -        NaN
# 48                  biomass           1    0** or 1*        NaN
# 49                      NaN         NaN          NaN        NaN
# 50                      NAD           -            -  -0.000300
# 51                     NADP         NaN          NaN   0.000130
# 52                     NADH         NaN          NaN   0.000150
# 53                    NADPH         NaN          NaN   0.000100
# 54                      CoA         NaN          NaN   0.000136
# 55                      FAD         NaN          NaN   0.000100
# 56   Pyridoxal phosphate_c0         NaN          NaN   0.000100
# 57  S-Adenosyl-L-methionine         NaN          NaN  -0.000543
#
#                      PstKB_cobra
# 0                       0.028881
# 1                            NaN
# 2                       0.015417
# 3                       0.015417
# 4                       0.095373
# 5                            NaN
# 6                            NaN
# 7                       0.125715
# 8                            NaN
# 9                            NaN
# 10                      0.113681
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                      0.038393
# 18                           NaN
# 19                           NaN
# 20                      0.059905
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                      50.86403
# 34                     52.486878
# 35                           NaN
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                           NaN
# 41                           NaN
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                           NaN
# 50  Not included in this version
# 51  Not included in this version
# 52  Not included in this version
# 53  Not included in this version
# 54  Not included in this version
# 55                           NaN
# 56                           NaN
# 57                           NaN

# %% [markdown]
# # Crear la Tabla "Rosseta"
#
# crear el indice entre Metablolito - Reaccion Name, para poder unificar las tablas, y luego poder remplazar los valores

# %%
# Configurar pandas para mostrar todas las filas
pd.set_option('display.max_rows', None)
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)
# Restaurar la configuración predeterminada al final de la celda
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
# Limpiar la columna "Reaction Name"
mergeDf['Reaction Name'] = mergeDf['Reaction Name'].str.replace(' ', '').str.replace(',', '').str.replace('_c0', '')

mergeDf
# Out:
#               ID                   Reaction Name        KB      Guevara
# 0   cpd00001[c0]                             H2O        30       52.486
# 1   cpd00003[c0]                             NAD    0.0003       0.0003
# 2   cpd00002[c0]                             ATP    30.027       50.864
# 3   cpd00006[c0]                            NADP   0.00013      0.00013
# 4   cpd00004[c0]                            NADH   0.00015      0.00015
# 5   cpd00005[c0]                           NADPH    0.0001       0.0001
# 6   cpd00010[c0]                             CoA  0.000136     0.000136
# 7   cpd00062[c0]                             UTP     0.027  0.095373121
# 8   cpd00015[c0]                             FAD    0.0001       0.0001
# 9   cpd00050[c0]                             FMN    0.0001       0.0001
# 10  cpd00016[c0]              Pyridoxalphosphate    0.0001       0.0001
# 11  cpd00017[c0]         S-Adenosyl-L-methionine  0.000543     0.000543
# 12  cpd00060[c0]                    L-Methionine     0.049  0.038393076
# 13  cpd00130[c0]                        L-Malate     0.037        0.037
# 14  cpd00023[c0]                     L-Glutamate      0.13  0.113680655
# 15  cpd00053[c0]                     L-Glutamine     0.071  0,059905153
# 16  cpd00035[c0]                       L-Alanine     0.161  0.125715444
# 17  cpd00038[c0]                             GTP     0.026        0.026
# 18  cpd00032[c0]                    Oxaloacetate    0.0757       0.0757
# 19  cpd00137[c0]                         Citrate     0.013        0.013
# 20  cpd00041[c0]                     L-Aspartate     0.098        0.098
# 21  cpd00052[c0]                             CTP     0.026        0.026
# 22  cpd00132[c0]                    L-Asparagine     0.056        0.056
# 23  cpd00054[c0]                        L-Serine       0.1          0.1
# 24  cpd00056[c0]                             TPP    0.0001       0.0001
# 25  cpd00033[c0]                         Glycine      0.15         0.15
# 26  cpd00066[c0]                 L-Phenylalanine     0.074        0.074
# 27  cpd00159[c0]                       L-Lactate     0.039        0.039
# 28  cpd00069[c0]                      L-Tyrosine     0.049        0.049
# 29  cpd00161[c0]                     L-Threonine     0.096        0.096
# 30  cpd00080[c0]            Glycerol-3-phosphate      0.13         0.13
# 31  cpd00087[c0]                Tetrahydrofolate    0.0001       0.0001
# 32  cpd00201[c0]       10-Formyltetrahydrofolate    0.0001       0.0001
# 33  cpd00125[c0]  5-10-Methylenetetrahydrofolate    0.0001       0.0001
# 34  cpd00345[c0]        5-Methyltetrahydrofolate    0.0001       0.0001
# 35  cpd00115[c0]                            dATP      0.03  0.028880831
# 36  cpd00347[c0]   5-10-Methenyltetrahydrofolate    0.0001       0.0001
# 37  cpd00129[c0]                       L-Proline     0.096        0.096
# 38  cpd00331[c0]                   cis-Aconitate     0.086        0.086
# 39  cpd00163[c0]                      UDP-xylose     0.766        0.766
# 40  cpd00604[c0]                     4-Coumarate      0.55         0.55
# 41  cpd00241[c0]                            dGTP     0.026  0,015417221
# 42  cpd00357[c0]                             TTP      0.03         0.03
# 43  cpd01059[c0]                        Ferulate     0.076        0.076
# 44  cpd02197[c0]        5-Formyltetrahydrofolate    0.0001       0.0001
# 45  cpd00356[c0]                            dCTP     0.026  0,015417221
# 46  cpd00834[c0]              Phosphopantetheine     0.001        0.001
# 47  cpd00084[c0]                      L-Cysteine     0.029        0.029
# 48  cpd00205[c0]                              K+     0.307        0.307
# 49  cpd00065[c0]                    L-Tryptophan     0.024        0.024
# 50  cpd00156[c0]                        L-Valine     0.127        0.127
# 51  cpd00051[c0]                      L-Arginine      0.11         0.11
# 52  cpd00099[c0]                             Cl-      0.21         0.21
# 53  cpd00214[c0]                       Palmitate     0.329        0.329
# 54  cpd00119[c0]                     L-Histidine     0.038        0.038
# 55  cpd00322[c0]                    L-Isoleucine     0.083        0.083
# 56  cpd00107[c0]                       L-Leucine     0.172        0.172
# 57  cpd00039[c0]                        L-Lysine     0.096        0.096
# 58  cpd01080[c0]                           ocdca     0.011        0.011
# 59  cpd19001[c0]                 alpha-D-Glucose      1.59         1.59
# 60  cpd30321[c0]                 beta-D-Fructose    0.2271       0.2271
# 61  cpd16443[c0]             beta-D-Ribofuranose    0.0377       0.0377
# 62  cpd00104[c0]                            BIOT    0.0001       0.0001
# 63  cpd12844[d0]                  Phytonadiol_d0  0.000975     0.000975
# 64  cpd00536[c0]                          Oleate     0.015        0.015
# 65  cpd25914[c0]                    ubiquinol(9)    0.0001       0.0001
# 66  cpd16503[c0]                  Plastoquinol-9  0.000155     0.000155
# 67  cpd00009[c0]                       Phosphate        30           30
# 68  cpd00012[c0]                             PPi     0.218        0.218
# 69  cpd00067[c0]                              H+        30           30
# 70  cpd00008[c0]                             ADP        30           30
# 71  cpd00014[c0]                             UDP     0.766        0.766
# 72  cpd11416[c0]                         Biomass       NaN          NaN

# %%
from fuzzywuzzy import fuzz
# Crear una función para encontrar la mejor coincidencia con fuzzywuzzy
def find_best_match(string_to_match, candidates):
    if isinstance(string_to_match, float):
        return None, 0  # Si es un valor float, devuelve valores predeterminados

    best_match = None
    highest_similarity = -1

    for candidate in candidates:
        similarity = fuzz.ratio(string_to_match, candidate)
        if similarity > highest_similarity:
            highest_similarity = similarity
            best_match = candidate

    return best_match, highest_similarity

# Aplicar la función a cada fila en comp_Table['Metabolito']
comp_Table['Best_Match'], comp_Table['Similarity'] = zip(*comp_Table['Metabolito'].apply(lambda x: find_best_match(x, mergeDf['Reaction Name'])))

# Establecer un umbral de similitud para considerar coincidencias
umbral_similitud = 80

# Filtrar las filas que cumplen con el umbral de similitud
matching_rows = comp_Table[comp_Table['Similarity'] >= umbral_similitud]

# Realizar el merge basado en las coincidencias
comparacion_de_datos = pd.merge(mergeDf, matching_rows, how='left', left_on='Reaction Name', right_on='Best_Match', suffixes=('', '_comp'))

# Agregar las filas que no encontraron coincidencias
filas_sin_coincidencia = comp_Table[comp_Table['Similarity'] < umbral_similitud].copy()
filas_sin_coincidencia['Reaction Name'] = None  # Establecer la columna de coincidencia como None para indicar falta de coincidencia
comparacion_de_datos = pd.concat([comparacion_de_datos, filas_sin_coincidencia], ignore_index=True)

# Eliminar columnas temporales
comparacion_de_datos = comparacion_de_datos.drop(['Best_Match', 'Similarity'], axis=1)

# Imprimir el DataFrame resultante
comparacion_de_datos
# Out:
#               ID                   Reaction Name        KB      Guevara  \
# 0   cpd00001[c0]                             H2O        30       52.486
# 1   cpd00003[c0]                             NAD    0.0003       0.0003
# 2   cpd00002[c0]                             ATP    30.027       50.864
# 3   cpd00006[c0]                            NADP   0.00013      0.00013
# 4   cpd00004[c0]                            NADH   0.00015      0.00015
# 5   cpd00005[c0]                           NADPH    0.0001       0.0001
# 6   cpd00010[c0]                             CoA  0.000136     0.000136
# 7   cpd00062[c0]                             UTP     0.027  0.095373121
# 8   cpd00015[c0]                             FAD    0.0001       0.0001
# 9   cpd00050[c0]                             FMN    0.0001       0.0001
# 10  cpd00016[c0]              Pyridoxalphosphate    0.0001       0.0001
# 11  cpd00017[c0]         S-Adenosyl-L-methionine  0.000543     0.000543
# 12  cpd00060[c0]                    L-Methionine     0.049  0.038393076
# 13  cpd00130[c0]                        L-Malate     0.037        0.037
# 14  cpd00023[c0]                     L-Glutamate      0.13  0.113680655
# 15  cpd00053[c0]                     L-Glutamine     0.071  0,059905153
# 16  cpd00035[c0]                       L-Alanine     0.161  0.125715444
# 17  cpd00038[c0]                             GTP     0.026        0.026
# 18  cpd00032[c0]                    Oxaloacetate    0.0757       0.0757
# 19  cpd00137[c0]                         Citrate     0.013        0.013
# 20  cpd00041[c0]                     L-Aspartate     0.098        0.098
# 21  cpd00052[c0]                             CTP     0.026        0.026
# 22  cpd00132[c0]                    L-Asparagine     0.056        0.056
# 23  cpd00054[c0]                        L-Serine       0.1          0.1
# 24  cpd00056[c0]                             TPP    0.0001       0.0001
# 25  cpd00033[c0]                         Glycine      0.15         0.15
# 26  cpd00066[c0]                 L-Phenylalanine     0.074        0.074
# 27  cpd00159[c0]                       L-Lactate     0.039        0.039
# 28  cpd00069[c0]                      L-Tyrosine     0.049        0.049
# 29  cpd00161[c0]                     L-Threonine     0.096        0.096
# 30  cpd00080[c0]            Glycerol-3-phosphate      0.13         0.13
# 31  cpd00087[c0]                Tetrahydrofolate    0.0001       0.0001
# 32  cpd00201[c0]       10-Formyltetrahydrofolate    0.0001       0.0001
# 33  cpd00125[c0]  5-10-Methylenetetrahydrofolate    0.0001       0.0001
# 34  cpd00345[c0]        5-Methyltetrahydrofolate    0.0001       0.0001
# 35  cpd00115[c0]                            dATP      0.03  0.028880831
# 36  cpd00347[c0]   5-10-Methenyltetrahydrofolate    0.0001       0.0001
# 37  cpd00129[c0]                       L-Proline     0.096        0.096
# 38  cpd00331[c0]                   cis-Aconitate     0.086        0.086
# 39  cpd00163[c0]                      UDP-xylose     0.766        0.766
# 40  cpd00604[c0]                     4-Coumarate      0.55         0.55
# 41  cpd00241[c0]                            dGTP     0.026  0,015417221
# 42  cpd00357[c0]                             TTP      0.03         0.03
# 43  cpd01059[c0]                        Ferulate     0.076        0.076
# 44  cpd02197[c0]        5-Formyltetrahydrofolate    0.0001       0.0001
# 45  cpd00356[c0]                            dCTP     0.026  0,015417221
# 46  cpd00834[c0]              Phosphopantetheine     0.001        0.001
# 47  cpd00084[c0]                      L-Cysteine     0.029        0.029
# 48  cpd00205[c0]                              K+     0.307        0.307
# 49  cpd00065[c0]                    L-Tryptophan     0.024        0.024
# 50  cpd00156[c0]                        L-Valine     0.127        0.127
# 51  cpd00051[c0]                      L-Arginine      0.11         0.11
# 52  cpd00099[c0]                             Cl-      0.21         0.21
# 53  cpd00214[c0]                       Palmitate     0.329        0.329
# 54  cpd00119[c0]                     L-Histidine     0.038        0.038
# 55  cpd00322[c0]                    L-Isoleucine     0.083        0.083
# 56  cpd00107[c0]                       L-Leucine     0.172        0.172
# 57  cpd00039[c0]                        L-Lysine     0.096        0.096
# 58  cpd01080[c0]                           ocdca     0.011        0.011
# 59  cpd19001[c0]                 alpha-D-Glucose      1.59         1.59
# 60  cpd30321[c0]                 beta-D-Fructose    0.2271       0.2271
# 61  cpd16443[c0]             beta-D-Ribofuranose    0.0377       0.0377
# 62  cpd00104[c0]                            BIOT    0.0001       0.0001
# 63  cpd12844[d0]                  Phytonadiol_d0  0.000975     0.000975
# 64  cpd00536[c0]                          Oleate     0.015        0.015
# 65  cpd25914[c0]                    ubiquinol(9)    0.0001       0.0001
# 66  cpd16503[c0]                  Plastoquinol-9  0.000155     0.000155
# 67  cpd00009[c0]                       Phosphate        30           30
# 68  cpd00012[c0]                             PPi     0.218        0.218
# 69  cpd00067[c0]                              H+        30           30
# 70  cpd00008[c0]                             ADP        30           30
# 71  cpd00014[c0]                             UDP     0.766        0.766
# 72  cpd11416[c0]                         Biomass       NaN          NaN
# 73           NaN                            None       NaN          NaN
# 74           NaN                            None       NaN          NaN
# 75           NaN                            None       NaN          NaN
# 76           NaN                            None       NaN          NaN
# 77           NaN                            None       NaN          NaN
# 78           NaN                            None       NaN          NaN
# 79           NaN                            None       NaN          NaN
# 80           NaN                            None       NaN          NaN
# 81           NaN                            None       NaN          NaN
# 82           NaN                            None       NaN          NaN
# 83           NaN                            None       NaN          NaN
# 84           NaN                            None       NaN          NaN
# 85           NaN                            None       NaN          NaN
# 86           NaN                            None       NaN          NaN
# 87           NaN                            None       NaN          NaN
# 88           NaN                            None       NaN          NaN
# 89           NaN                            None       NaN          NaN
# 90           NaN                            None       NaN          NaN
# 91           NaN                            None       NaN          NaN
# 92           NaN                            None       NaN          NaN
# 93           NaN                            None       NaN          NaN
# 94           NaN                            None       NaN          NaN
# 95           NaN                            None       NaN          NaN
# 96           NaN                            None       NaN          NaN
# 97           NaN                            None       NaN          NaN
#
#                  Metabolito Botero 2018 Guevara 2023  PstKB_Ori  \
# 0                       H2O           -    52.486878  30.000000
# 1                       NAD           -            -  -0.000300
# 2                       ATP           1     50.86403 -30.027000
# 3                      NADP         NaN          NaN   0.000130
# 4                      NADH         NaN          NaN   0.000150
# 5                     NADPH         NaN          NaN   0.000100
# 6                       CoA         NaN          NaN   0.000136
# 7                       UTP      0.0028     0.095373   0.027000
# 8                       FAD         NaN          NaN   0.000100
# 9                       NaN         NaN          NaN        NaN
# 10   Pyridoxal phosphate_c0         NaN          NaN   0.000100
# 11  S-Adenosyl-L-methionine         NaN          NaN  -0.000543
# 12               methionine       0.002     0.038393   0.049000
# 13                      NaN         NaN          NaN        NaN
# 14                      NaN         NaN          NaN        NaN
# 15                glutamine        0.35     0.059905   0.071000
# 16                      NaN         NaN          NaN        NaN
# 17                      GTP      0.0039     0.059181        NaN
# 18                      NaN         NaN          NaN        NaN
# 19                      NaN         NaN          NaN        NaN
# 20                      NaN         NaN          NaN        NaN
# 21                      CTP      0.0032     0.050418        NaN
# 22               asparagine        0.39     0.070447        NaN
# 23                      NaN         NaN          NaN        NaN
# 24                      NaN         NaN          NaN        NaN
# 25                  glycine        0.14     0.119759        NaN
# 26            phenylalanine        0.08     0.066998        NaN
# 27                      NaN         NaN          NaN        NaN
# 28                      NaN         NaN          NaN        NaN
# 29                threonine       0.086     0.084449        NaN
# 30                      NaN         NaN          NaN        NaN
# 31                      NaN         NaN          NaN        NaN
# 32                      NaN         NaN          NaN        NaN
# 33                      NaN         NaN          NaN        NaN
# 34                      NaN         NaN          NaN        NaN
# 35                     dATP      0.0027     0.028881   0.030000
# 36                      NaN         NaN          NaN        NaN
# 37                      NaN         NaN          NaN        NaN
# 38                      NaN         NaN          NaN        NaN
# 39                 D-xylose       0.282        0.282        NaN
# 40                      NaN         NaN          NaN        NaN
# 41                     dGTP     0.00166     0.015417   0.026000
# 42                     dTTP      0.0028     0.028881        NaN
# 43                      NaN         NaN          NaN        NaN
# 44                      NaN         NaN          NaN        NaN
# 45                     dCTP      0.0018     0.015417   0.026000
# 46                      NaN         NaN          NaN        NaN
# 47                      NaN         NaN          NaN        NaN
# 48                      NaN         NaN          NaN        NaN
# 49               tryptophan        0.04     0.018506        NaN
# 50                      NaN         NaN          NaN        NaN
# 51                      NaN         NaN          NaN        NaN
# 52                      NaN         NaN          NaN        NaN
# 53                      NaN         NaN          NaN        NaN
# 54                histidine           -     0.034132        NaN
# 55               isoleucine        0.06     0.089036        NaN
# 56                      NaN         NaN          NaN        NaN
# 57                      NaN         NaN          NaN        NaN
# 58                      NaN         NaN          NaN        NaN
# 59          alpha-D-glucose       0.053        0.053        NaN
# 60          beta-D-fructose       0.053            -        NaN
# 61                      NaN         NaN          NaN        NaN
# 62                      NaN         NaN          NaN        NaN
# 63                      NaN         NaN          NaN        NaN
# 64                      NaN         NaN          NaN        NaN
# 65                      NaN         NaN          NaN        NaN
# 66                      NaN         NaN          NaN        NaN
# 67                      NaN         NaN          NaN        NaN
# 68                       Pi          30    50.821625        NaN
# 69                       H+         NaN    50.821625        NaN
# 70                      ADP          30    50.821625        NaN
# 71                      NaN         NaN          NaN        NaN
# 72                  biomass           1    0** or 1*        NaN
# 73                  alanine       0.107     0.125715   0.161000
# 74                 cysteine       0.024     0.023571        NaN
# 75            aspartic acid       0.162       0.0922        NaN
# 76            glutamic acid        0.39     0.113681   0.130000
# 77                   lysine       0.001     0.111221   0.096000
# 78                  leucine        0.14     0.149333        NaN
# 79                  proline        0.01     0.084621        NaN
# 80                 arginine           -     0.083304        NaN
# 81                   serine        0.21     0.136486        NaN
# 82                   valine           -     0.115457        NaN
# 83                 tyrosine        0.03     0.048038        NaN
# 84         palmitoleic acid           1      0.04043        NaN
# 85            palmitic acid           -     0.000304        NaN
# 86           linolenic acid           -     0.118671        NaN
# 87            linoleic acid           -     0.040003        NaN
# 88             stearic acid           -     0.000455        NaN
# 89               oleic acid           -     0.003467        NaN
# 90                      Ppi         NaN     0.251164        NaN
# 91        Coniferyl alcohol       0.048        0.048        NaN
# 92          synapyl alcohol       0.056        0.056        NaN
# 93         coumaryl alcohol        0.04         0.04        NaN
# 94                  sucrose       0.096            -        NaN
# 95                cellulose       0.305            -        NaN
# 96                   starch       0.265            -        NaN
# 97                      NaN         NaN          NaN        NaN
#
#                      PstKB_cobra
# 0                      52.486878
# 1   Not included in this version
# 2                       50.86403
# 3   Not included in this version
# 4   Not included in this version
# 5   Not included in this version
# 6   Not included in this version
# 7                       0.095373
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                      0.038393
# 13                           NaN
# 14                           NaN
# 15                      0.059905
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                           NaN
# 34                           NaN
# 35                      0.028881
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                           NaN
# 41                      0.015417
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                      0.015417
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                           NaN
# 50                           NaN
# 51                           NaN
# 52                           NaN
# 53                           NaN
# 54                           NaN
# 55                           NaN
# 56                           NaN
# 57                           NaN
# 58                           NaN
# 59                           NaN
# 60                           NaN
# 61                           NaN
# 62                           NaN
# 63                           NaN
# 64                           NaN
# 65                           NaN
# 66                           NaN
# 67                           NaN
# 68                           NaN
# 69                           NaN
# 70                           NaN
# 71                           NaN
# 72                           NaN
# 73                      0.125715
# 74                           NaN
# 75                           NaN
# 76                      0.113681
# 77                           NaN
# 78                           NaN
# 79                           NaN
# 80                           NaN
# 81                           NaN
# 82                           NaN
# 83                           NaN
# 84                           NaN
# 85                           NaN
# 86                           NaN
# 87                           NaN
# 88                           NaN
# 89                           NaN
# 90                           NaN
# 91                           NaN
# 92                           NaN
# 93                           NaN
# 94                           NaN
# 95                           NaN
# 96                           NaN
# 97                           NaN

# %%
# Especifica la ruta y nombre del archivo Excel
excel_filename = 'comparacion_de_datos.xlsx'

# Exporta el DataFrame a un archivo Excel
comparacion_de_datos.to_excel(excel_filename, index=False)

# %%
# Suponiendo que comparacion_de_datos y PstKB_OF son tus DataFrames

# Realizar el merge utilizando la columna 'ID' como clave
merged_dataframe = pd.merge(comparacion_de_datos, PstKB_OF, on='ID', how='inner')

# Imprimir el DataFrame resultante
merged_dataframe.to_excel('TODO.xlsx',index=False)
